# %% [markdown]
# # Damped Traub's method without different colors

# %%
from utils import *

# %%
def f(z):
    return z**3 -1

def der_f(z):
    return 3*z**2
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1, max_iter=60)

# %%
def f(z):
    return z*(z-1j)*(z-1)

def der_f(z):
    return (z-1j)*(z-1) + z*(z-1j) + z*(z-1)
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1, max_iter=60)

# %%
def f(z):
    return (z**2 + 0.25)*(z-0.439)

def der_f(z):
    return 2*z*(z-0.439) + (z**2 + 0.25)
plot_damped_traub(f, der_f, xmin=-0.8,xmax=0.8, ymin=-0.8, ymax=0.8, delta = 1, max_iter=60)

# %%
def f(z):
    return z*(z-0.2)*(z-(0.5+0.5j))*(z+(0.5+0.5j))*(z-1j)

def der_f(z):
    return 5*(-(0.16+0.8j)*z**3 -(0.2-0.04j)*z + z**4 - (0.18j)*z**2 + 0.02)
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z**3 -1

def der_f(z):
    return 3*z**2
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1, max_iter=60)

# %%
def f(z):
    return z**4 -1

def der_f(z):
    return 4*z**3
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1, max_iter=60)

# %%
a = -0.967967967967968-0.0010010010010009784j
def f(z):
    return z*(z-1)*(z-a)

def der_f(z):
    return 3*z**2 - 2*(1+a)*z + a
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1, max_iter=50)
