# %%
from utils import *

# %%
def f(z):
    return (z**2 + 0.25)*(z-0.439)

def der_f(z):
    return 2*z*(z-0.439) + (z**2 + 0.25)
plot_damped_traub(f, der_f, xmin=-0.8,xmax=0.8, ymin=-0.8, ymax=0.8, delta = 1)

# %% [markdown]
# # Colored plot of the damped Traub method

# %%
def f(z):
    return (z**2 + 0.25)*(z-0.439)

def der_f(z):
    return 2*z*(z-0.439) + (z**2 + 0.25)

roots = [0.439, (-0.25)**(1/2), -(-0.25)**(1/2)]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub(f, der_f, (-0.8,0.8), (-0.8,0.8), 1024,1024,roots, colors, delta = 1)

# %%
def f(z):
    return z**3 -1

def der_f(z):
    return 3*z**2
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z**3 -1

def der_f(z):
    return 3*z**2
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0)

# %%
def f(z):
    return z**4 -1

def der_f(z):
    return 4*z**3
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z*z*z*z*z -1

def der_f(z):
    return 5*z**4
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z*z -1

def der_f(z):
    return 2*z
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z*z -1

def der_f(z):
    return 2*z
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0)

# %% [markdown]
# # Progression damped Traub method, delta from 0 to 1

# %%
def f(z):
    return z*(z-1j)*(z-1)

def der_f(z):
    return (z-1j)*(z-1) + z*(z-1j) + z*(z-1)
plot_damped_traub(f,der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0)

# %%
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0.2)

# %%
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0.4)

# %%
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0.6)

# %%
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0.8)

# %%
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)
