# %%
from utils import *

# %%
def f(z):
    return (z**2 + 0.25)*(z-0.439)

def der_f(z):
    return 2*z*(z-0.439) + (z**2 + 0.25)
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-0.8,xmax=0.8, ymin=-0.8, ymax=0.8, delta = 1)

# %%
plot_damped_traub(f, der_f, xmin=-0.8,xmax=0.8, ymin=-0.8, ymax=0.8, delta = 1)

# %%
def f(z):
    return z**4 -1

def der_f(z):
    return 4*z**3
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0)

# %%
def f(z):
    return z*z*z*z*z -1

def der_f(z):
    return 5*z**4
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z**3 -1

def der_f(z):
    return 3*z**2
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z**3 -1

def der_f(z):
    return 3*z**2
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0)

# %%
def f(z):
    return z**3 -1

def der_f(z):
    return 3*z**2
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0.5)

# %%
def f(z):
    return z*z -1

def der_f(z):
    return 2*z
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1)

# %%
def f(z):
    return z*z -1

def der_f(z):
    return 2*z
plot_damped_traub(lambda z: f(z), lambda z: der_f(z), xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 0) # viridis palette

# %%
def f(z):
    return z*z -1

def der_f(z):
    return 2*z
plot_damped_traub(f, der_f, xmin=-2,xmax=2, ymin=-2, ymax=2, delta = 1, N = 2000)
