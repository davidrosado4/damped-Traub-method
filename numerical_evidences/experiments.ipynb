# %% [markdown]
# # Numerical evidences. Control of the critical points.

# %%
from utils import *

# %%
count_no_conv, data = evidences_critical_points_control()
# Out:
# {'a': (-0.967967967967968-0.0010010010010009784j), 'crit': (0.46515095881421187+3.5737117823647635e-05j), 'root': (0.46546559957218714+0.0015151162673774556j), 'iterations': 560}
# {'a': (-0.967967967967968+0.0010010010010010895j), 'crit': (0.46515095881421187-3.5737117823638365e-05j), 'root': (0.46546559957218736-0.0015151162673784878j), 'iterations': 560}

# %%
count_no_conv
# Out:
# 2

# %%
data

# %%
parameter_plane_a(delta=0)

# %%
parameter_plane_a(delta=0,xmin=0.07,xmax=0.13,ymin=0.39,ymax=0.45)

# %% [markdown]
# ## Continutation of free critical and  new fixed points

# %% [markdown]
# Case a=2

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.26,0.6), (-0.1,0.1), 1024,1024,roots, colors, delta = 0.01,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.26,0.6), (-0.1,0.1), 1024,1024,roots, colors, delta = 0.1,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.1,0.7), (-0.25,0.25), 1024,1024,roots, colors, delta = 0.5,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0,1), (-0.4,0.4), 1024,1024,roots, colors, delta = 0.99,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2right(f, der_f, (1.35,1.7), (-0.1,0.1), 1024,1024,roots, colors, delta = 0.01,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2right(f, der_f, (1.35,1.7), (-0.1,0.1), 1024,1024,roots, colors, delta = 0.1,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2right(f, der_f, (1.35,1.9), (-0.25,0.25), 1024,1024,roots, colors, delta = 0.5,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2right(f, der_f, (1.03,2.01), (-0.4,0.4), 1024,1024,roots, colors, delta = 0.99,print_free_fixed=True)

# %% [markdown]
# Case a=6

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.4,0.55), (-0.07,0.07), 1024,1024,roots, colors, delta = 0.01,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.3,0.65), (-0.1,0.1), 1024,1024,roots, colors, delta = 0.1,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.2,0.75), (-0.12,0.12), 1024,1024,roots, colors, delta = 0.3,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.1,0.85), (-0.15,0.15), 1024,1024,roots, colors, delta = 0.5,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0,0.92), (-0.15,0.15), 1024,1024,roots, colors, delta = 0.7,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (-0.01,1.01), (-0.15,0.15), 1024,1024,roots, colors, delta = 0.99,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6right(f, der_f, (3.2,4.5), (-0.5,0.5), 1024,1024,roots, colors, delta = 0.01,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6right(f, der_f, (3.2,4.9), (-0.6,0.6), 1024,1024,roots, colors, delta = 0.1,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6right(f, der_f, (3.2,5.35), (-0.68,0.68), 1024,1024,roots, colors, delta = 0.3,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6right(f, der_f, (3.2,5.6), (-0.75,0.75), 1024,1024,roots, colors, delta = 0.5,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6right(f, der_f, (3.15,6), (-0.88,0.88), 1024,1024,roots, colors, delta = 0.7,print_free_fixed=True)

# %%
def f(z):
    return z * (z - 1) * (z - 6)


def der_f(z):
    return 3 * z ** 2 - 14 * z + 6


roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6right(f, der_f, (3.15, 6.03), (-0.93, 0.93), 1024, 1024, roots, colors, delta=0.99,print_free_fixed=True)
