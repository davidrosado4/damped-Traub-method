# %% [markdown]
# # Parameter plane of damped Traub's method

# %%
from utils import *
plot_parameter_plane()

# %%
from utils import *
# showing hyperbolic component K
plot_parameter_plane()
# Out:
# /Users/davidrosado/Desktop/MAM/TFM/code/utils.py:231: RuntimeWarning: overflow encountered in cdouble_scalars
#   z_new = (z*z)*((z*z + 2*z + (1-delta))/((1-delta)*z*z + 2*z + 1))
# /Users/davidrosado/Desktop/MAM/TFM/code/utils.py:231: RuntimeWarning: invalid value encountered in cdouble_scalars
#   z_new = (z*z)*((z*z + 2*z + (1-delta))/((1-delta)*z*z + 2*z + 1))
